# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh06961/DBS_Lab/blob/main/6a_DES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from Crypto.Cipher import DES
from Crypto.Util.Padding import pad, unpad
from Crypto.Random import get_random_bytes
import binascii

key = get_random_bytes(8)
print("DES Symmetric key (hex):", binascii.hexlify(key).decode())

msg = input("Enter message to encrypt: ")

cipher = DES.new(key, DES.MODE_CBC)
ct_bytes = cipher.iv + cipher.encrypt(pad(msg.encode(), DES.block_size))
print("Encrypted (hex):", binascii.hexlify(ct_bytes).decode())

iv = ct_bytes[:DES.block_size]
ciphertext = ct_bytes[DES.block_size:]
decipher = DES.new(key, DES.MODE_CBC, iv)
pt = unpad(decipher.decrypt(ciphertext), DES.block_size)
print("Decrypted:", pt.decode())
# Out:
# DES Symmetric key (hex): 9e6d1bde46e6d692
# Enter message to encrypt: Hi, I'm Dinesh
# Encrypted (hex): b578c0bef533b3ac7aa3bea7c2ca9d53bce2bb343df255e0
# Decrypted: Hi, I'm Dinesh
