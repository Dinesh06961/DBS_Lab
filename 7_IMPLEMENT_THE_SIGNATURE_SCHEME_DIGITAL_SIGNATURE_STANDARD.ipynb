# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh06961/DBS_Lab/blob/main/7_IMPLEMENT_THE_SIGNATURE_SCHEME_DIGITAL_SIGNATURE_STANDARD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from sympy import isprime, nextprime, mod_inverse

# Short DSA simulation
p = nextprime(10600)
q = nextprime((p - 1) // 2)
g = pow(random.randint(2, p - 1), (p - 1) // q, p)

print("\n--- DIGITAL SIGNATURE ALGORITHM (DSA) ---\n")
print(f"Public parameters:\np = {p}\nq = {q}\ng = {g}")

# Key generation
x = random.randint(1, q - 1)   # private key
y = pow(g, x, p)               # public key
print(f"\nPrivate key (x): {x}\nPublic key (y): {y}")

# Signature generation
k = random.randint(1, q - 1)
r = pow(g, k, p) % q
h = random.randint(1, p - 1)   # pretend hash value
s = (mod_inverse(k, q) * (h + x * r)) % q
print(f"\nSignature:\nr = {r}\ns = {s}")

# Signature verification
w = mod_inverse(s, q)
u1 = (h * w) % q
u2 = (r * w) % q
v = ((pow(g, u1, p) * pow(y, u2, p)) % p) % q

print("\nVerification results:")
print(f"v = {v}\nr = {r}")
print("\n✅ Signature Verified!" if v == r else "\n❌ Signature Verification Failed!")
# Out:
# --- DIGITAL SIGNATURE ALGORITHM (DSA) ---
#
# Public parameters:
# p = 10601
# q = 5303
# g = 7851
#
# Private key (x): 823
# Public key (y): 1543
#
# Signature:
# r = 1653
# s = 1818
#
# Verification results:
# v = 1748
# r = 1653
#
# ❌ Signature Verification Failed!
