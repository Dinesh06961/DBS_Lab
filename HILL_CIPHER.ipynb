# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh06961/DBS_Lab/blob/main/HILL_CIPHER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
def main():
    a = np.array([[6, 24, 1], [13, 16, 10], [20, 17, 15]], dtype=np.uint32)
    b = np.array([[8, 5, 10], [21, 8, 21], [21, 12, 8]], dtype=np.uint32)
    c = [0] * 20
    d = [0] * 20
    msg = input("Enter plain text: ")
    for i in range(len(msg)):
        c[i] = ord(msg[i]) - 65
        print(c[i], end=" ")
    for i in range(3):
        t = 0
        for j in range(3):
            t += a[i][j] * c[j]
        d[i] = t % 26
    print("\nEncrypted Cipher Text :", end="")
    for i in range(3):
        print(" ", chr(d[i] + 65), end="")
    for i in range(3):
        t = 0
        for j in range(3):
            t += b[i][j] * d[j]
        c[i] = t % 26
    print("\nDecrypted Cipher Text :", end="")
    for i in range(3):
        print(" ", chr(c[i] + 65), end="")
if __name__ == "__main__":
    main()
# Out:
# Enter plain text: Dinesh
# 3 40 45 36 50 39
# Encrypted Cipher Text :  J  L  L
# Decrypted Cipher Text :  D  O  T
