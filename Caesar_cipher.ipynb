# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh06961/DBS_Lab/blob/main/Caesar_cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def caesar_cipher():
    plain = input("Enter the plain text: ")
    key = int(input("Enter the key value: "))

    print("\n\tPLAIN TEXT:", plain)
    print("\n\tENCRYPTED TEXT:", end=' ')

    cipher = ''
    for char in plain:
        if char.isupper():
            cipher_char = chr((ord(char) + key - 65) % 26 + 65)
        elif char.islower():
            cipher_char = chr((ord(char) + key - 97) % 26 + 97)
        else:
            cipher_char = char
        cipher += cipher_char
        print(cipher_char, end='')

    print("\n\n\tAFTER DECRYPTION:", end=' ')

    decrypted = ''
    for char in cipher:
        if char.isupper():
            plain_char = chr((ord(char) - key - 65) % 26 + 65)
        elif char.islower():
            plain_char = chr((ord(char) - key - 97) % 26 + 97)
        else:
            plain_char = char
        decrypted += plain_char
        print(plain_char, end='')

    print()


if __name__ == "__main__":
    caesar_cipher()
# Out:
# Enter the plain text: I am Dinesh
# Enter the key value: 3
#
# 	PLAIN TEXT: I am Dinesh
#
# 	ENCRYPTED TEXT: L dp Glqhvk
#
# 	AFTER DECRYPTION: I am Dinesh
