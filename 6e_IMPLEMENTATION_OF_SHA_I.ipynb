# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh06961/DBS_Lab/blob/main/6e_IMPLEMENTATION_OF_SHA_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
def sha1():
    try:
        md = hashlib.sha1()
        print("Message digest object info: ")
        print(f" Algorithm = {md.name}")
        print(f" Provider = {hashlib.__name__}")
        print(f" ToString = {md}")

        input_str = ""
        md.update(input_str.encode())
        output = md.digest()
        print()
        print(f"SHA1(\"{input_str}\") = {bytes_to_hex(output)}")

        input_str = "abc"
        md = hashlib.sha1()
        md.update(input_str.encode())
        output = md.digest()
        print()
        print(f"SHA1(\"{input_str}\") = {bytes_to_hex(output)}")
        input_str = "abcdefghijklmnopqrstuvwxyz"
        md = hashlib.sha1()
        md.update(input_str.encode())
        output = md.digest()
        print()
        print(f"SHA1(\"{input_str}\") = {bytes_to_hex(output)}")
        print()
    except Exception as e:
        print(f"Exception: {e}")

def bytes_to_hex(b):
    return ''.join([f'{byte:02X}' for byte in b])

if __name__ == "__main__":
    sha1()
# Out:
# Message digest object info:
#  Algorithm = sha1
#  Provider = hashlib
#  ToString = <sha1 _hashlib.HASH object @ 0x79498755e410>
#
# SHA1("") = DA39A3EE5E6B4B0D3255BFEF95601890AFD80709
#
# SHA1("abc") = A9993E364706816ABA3E25717850C26C9CD0D89D
#
# SHA1("abcdefghijklmnopqrstuvwxyz") = 32D10C7B8CF96570CA04CE37F2A19D84240D3A89
